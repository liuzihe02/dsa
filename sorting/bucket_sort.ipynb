# %% [markdown]
# # BucketSort
#
# Bucket sort works well when the dataset to be sorted has **values within a specific range**. Rarely used in practice, needs to be constraints on range - lower and upper range. Only used during interviews when you know the range; try to spot if you know the range clearly.
#
# ## Concept
#
# Bucket sort is really simple. If we know a list has a range of `3 to 6`, then we simple keep a counter of `3,4,5,6`. We then search linearly the list and increment the counter for the respective value. Then we reconstruct the array, by overwriting the respective positions in the old array. The counters for each number is the 'bucket'.
#
# ![image.png](attachment:image.png)
#
# ```python
# def bucketSort(arr):
#     # Assuming arr only contains 0, 1 or 2
#     counts = [0, 0, 0]
#
#     # Count the quantity of each val in arr
#     for n in arr:
#         counts[n] += 1
#
#     # Reconstruct the sorted array by overwriting the old array
#
#     #i indexes the position in the old array
#     i = 0
#     #n tracks which value we care about
#     for n in range(len(counts)):
#         #this is just to fill in the value for n
#         for j in range(counts[n]):
#             arr[i] = n
#             i += 1
#     return arr
# ```

# %% [markdown]
# ## Time Complexity
#
# You might see the nested loop and think is is $O(n^2)$, but actually it is $O(n)$. This is since for the outer loop, we still go through the length of the array, so it is actually $O(n)$.
#
# | Algorithm | Big-O Time Complexity | Note |
# |:----------|:----------------------|:-----|
# | Insertion Sort | O(n²)* | If fully, or nearly sorted, O(n) |
# | Merge Sort | O(n log n) | |
# | Quick Sort | O(n log n)* | In worst case it is O(n²) |
# | Bucket Sort | O(n)* | Assuming all values in the input are in a specified range. |
#
# The `*` refers to the average case complexity. In general, safest bet is to use QuickSort or MergeSort
#
# ## Stability
#
# This alg is definitely not stable, as we dont keep track of the ordering of same values.
