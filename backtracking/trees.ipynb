# %% [markdown]
# # Backtracking
#
# A lot of overlap with DFS - its a brute-force approach and try all solutions like DFS but backtrack when we hit a dead end.

# %% [markdown]
# ## Problem: Find a valid path
#
# Given a binary tree, we want to determine if there exists a path from the root to a leaf node without having a value of `0` in the path. If such a path exists, we return `true`, otherwise we return `false`. We assume there exists only one such path.
#
# We try using DFS. Our constraint is that we cannot have a node with value `0` in our path. We also know that if the tree is empty, then there cannot exist a valid path either. Finally, if we reach a leaf node we can return true since it means there is a path that exists from root to leaf.
#
# 1. We can arbitrarily choose to explore the left-subtree first.
# 2. If the left-subtree returns `true`, we can return `true` as well.
# 3. If the left-subtree returns `false`, we can explore the right-subtree.
# 4. If the right-subtree returns `true`, we can return `true` as well.
# 5. If both the left and right subtrees return false, then we have to return `false`
#
# ![image.png](attachment:image.png)

# %%
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

def canReachLeaf(root):
    #if youve checked a null node or root.val==0
    if not root or root.val == 0:
        return False
    
    #reached a leaf node with no children at all
    if not root.left and not root.right:
        return True
    #recursively call left subtree
    if canReachLeaf(root.left):
        return True
    #if recursively call right subtree
    if canReachLeaf(root.right):
        return True
    
    #at this point, all the previous calls have been False
    return False

# %% [markdown]
# ### Building the Path
#
# Instead of returning `true` or `false`, we can build up the path and show the history travelled so far. We use a stack that increases as we traverse deeper, and pops stuff out as we backtrack
#
# ![image.png](attachment:image.png)

# %%
def leafPath(root, path):
    print(path)
    if not root or root.val == 0:
        return False
    path.append(root.val)

    if not root.left and not root.right:
        return True
    if leafPath(root.left, path):
        return True
    if leafPath(root.right, path):
        return True
    path.pop()
    return False

# %%
root=TreeNode(4)
root.left=TreeNode(0)
root.left.right=TreeNode(7)

root.right=TreeNode(1)
root.right.right=TreeNode(2)
root.right.left=TreeNode(3)
root.right.left.right=TreeNode(0)

print('final is outcome is',leafPath(root,[]))
# Out:
# []
# [4]
# [4]
# [4, 1]
# [4, 1, 3]
# [4, 1, 3]
# [4, 1]
# final is outcome is True

# %% [markdown]
# ---
#
# ### Time Complexity
#
# Given that the tree has `n` nodes, the time complexity will be $O(n)$ because in the worst case we may need to visit all the nodes in the tree.
#
# ### Space Complexity
#
# The space complexity is `h`, the height of the tree. This is because we are using recursion and the maximum depth of the recursion is the height of the tree.
#
# We are also storing the nodes along the path in the path list, which will have a maximum of $O(h)$ elements at any given time.

# %% [markdown]
# ---
#
# ## Problem: Subsets
#
# Given an integer array `nums` of unique elements, return all possible subsets (order isnt impt)
#
# The solution set must not contain duplicate subsets. Return the solution in any order.
#
# > In total we have $2^n$ subsets where $n$ is the length of the array. This is because for every item, we can either choose to include or not include it, so we have 2*2*2... different combinations of whether we choose to include it.
#
# Here's an example with the set `[1,2,3]`: at each layer we simply decide whether to add or not add the element we're considering. The solution is closer to BFS than DFS.
#
#
# ![image.png](attachment:image.png)

# %%
#mysol
def subsets(nums):
    #this is the history of arrangements that well return
    res = []
    #since this function is defined inside, we by default can access the variables outside it
    def dfs(i, sub):
        #terminate when i one index over the end
        if i==len(nums):
            res.append(sub)
            return
        #this is the subset after adding i, before the next i
        with_i=sub[:]
        with_i.append(nums[i])
        dfs(i+1,with_i)

        #this is the subset after not adding i
        dfs(i+1,sub)
    
    dfs(0,[])
    return res

# %%
def subsets(nums):
    res = []

    subset = []

    def dfs(i):
        if i >= len(nums):
            res.append(subset.copy())
            return
        subset.append(nums[i])
        dfs(i + 1)
        #this is literally just without the new elem, very similar to mine
        subset.pop()
        dfs(i + 1)

    dfs(0)
    return res

# %%
print(subsets([1,2,3]))
# Out:
# [[1, 2, 3], [1, 2], [1, 3], [1], [2, 3], [2], [3], []]

# %% [markdown]
# ## Combination Target Sum
#
# You are given an array of distinct integers `nums` and a target integer `target`. Your task is to return a list of all *unique combinations* of nums where the chosen numbers sum to `target`.
#
# The same number may be chosen from `nums` an *unlimited* number of times. Two combinations are the same if the frequency of each of the chosen numbers is the same, otherwise they are different.
#
# You may return the combinations in any order and the order of the numbers in each combination can be in any order.

# %%
def comboSum(nums, target):
    res = []
    combo = []

    def dfs(k, currsum):

        i=k%len(nums)

        print(f'Current sum: {currsum}, Current combination: {combo}')
        
        if currsum == target:
            res.append(combo.copy())
            return
        if currsum > target:
            print(f'TERMINATE: Current sum: {currsum}, Current combination: {combo}')
            return
        
        print(f'Trying to add the number {nums[i]} at {k}, real index {i}')

        combo.append(nums[i])
        print('first dfs')
        dfs(k + 1, currsum + nums[i])

        combo.pop()
        print('second dfs')
        dfs(k + 1, currsum)
        print('end loop')


    dfs(k=0, currsum=0)
    return res

# %%
def comboSum(nums,target):
    res = []

    def dfs(i, cur, total):
        if total == target:
            res.append(cur.copy())
            return
        if i >= len(nums) or total > target:
            return

        #append this number, and the next number to be added is still this number
        cur.append(nums[i])
        dfs(i, cur, total + nums[i])

        #do not append this current number, the next number adds the next number in the chronological index
        cur.pop()
        dfs(i + 1, cur, total)

    dfs(0, [], 0)
    return res

# %%
print(comboSum([2,5,6,9],9))
# Out:
# Current sum: 0, Current combination: []
# Trying to add the number 2 at 0, real index 0
# first dfs
# Current sum: 2, Current combination: [2]
# Trying to add the number 5 at 1, real index 1
# first dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 3, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 4, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 5, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 6, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 7, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 8, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 9, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 10, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 11, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 12, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 13, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 14, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 15, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 16, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 17, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 18, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 19, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 20, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 21, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 22, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 23, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 24, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 25, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 26, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 27, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 28, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 29, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 30, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 31, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 32, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 33, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 34, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 35, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 36, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 37, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 38, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 39, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 40, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 41, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 42, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 43, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 44, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 45, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 46, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 47, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 48, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 49, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 50, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 51, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 52, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 53, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 54, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 55, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 56, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 57, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 58, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 59, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 60, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 61, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 62, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 63, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 64, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 65, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 66, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 67, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 68, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 69, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 70, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 71, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 72, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 73, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 74, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 75, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 76, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 77, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 78, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 79, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 80, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 81, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 82, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 83, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 84, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 85, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 86, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 87, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 88, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 89, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 90, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 91, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 92, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 93, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 94, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 95, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 96, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 97, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 98, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 99, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 100, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 101, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 102, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 103, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 104, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 105, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 106, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 107, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 108, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 109, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 110, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 111, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 112, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 113, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 114, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 115, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 116, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 117, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 118, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 119, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 120, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 121, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 122, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 123, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 124, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 125, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 126, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 127, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 128, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 129, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 130, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 131, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 132, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 133, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 134, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 135, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 136, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 137, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 138, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 139, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 140, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 141, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 142, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 143, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 144, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 145, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 146, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 147, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 148, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 149, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 150, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 151, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 152, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 153, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 154, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 155, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 156, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 157, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 158, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 159, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 160, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 161, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 162, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 163, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 164, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 165, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 166, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 167, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 168, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 169, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 170, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 171, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 172, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 173, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 174, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 175, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 176, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 177, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 178, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 179, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 180, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 181, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 182, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 183, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 184, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 185, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 186, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 187, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 188, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 189, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 190, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 191, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 192, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 193, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 194, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 195, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 196, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 197, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 198, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 199, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 200, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 201, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 202, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 203, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 204, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 205, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 206, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 207, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 208, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 209, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 210, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 211, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 212, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 213, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 214, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 215, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 216, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 217, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 218, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 219, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 220, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 221, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 222, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 223, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 224, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 225, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 226, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 227, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 228, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 229, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 230, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 231, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 232, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 233, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 234, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 235, real index 3
# first dfs
# ...
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2903, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2904, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2905, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2906, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2907, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2908, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2909, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2910, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2911, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2912, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2913, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2914, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2915, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2916, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2917, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2918, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2919, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2920, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2921, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2922, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2923, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2924, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2925, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2926, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2927, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2928, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2929, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2930, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2931, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2932, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2933, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2934, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2935, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2936, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2937, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2938, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2939, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2940, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2941, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2942, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2943, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2944, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2945, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2946, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2947, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2948, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2949, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2950, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2951, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2952, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2953, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2954, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2955, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2956, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2957, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2958, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2959, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2960, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2961, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2962, real index 2
# first dfs
# Current sum: 13, Current combination: [2, 5, 6]
# TERMINATE: Current sum: 13, Current combination: [2, 5, 6]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 9 at 2963, real index 3
# first dfs
# Current sum: 16, Current combination: [2, 5, 9]
# TERMINATE: Current sum: 16, Current combination: [2, 5, 9]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 2 at 2964, real index 0
# first dfs
# Current sum: 9, Current combination: [2, 5, 2]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 5 at 2965, real index 1
# first dfs
# Current sum: 12, Current combination: [2, 5, 5]
# TERMINATE: Current sum: 12, Current combination: [2, 5, 5]
# second dfs
# Current sum: 7, Current combination: [2, 5]
# Trying to add the number 6 at 2966, real index 2
# first dfs
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 print(comboSum([2,5,6,9],9))
#
# Cell In[103], line 30, in comboSum(nums, target)
#      26     dfs(k + 1, currsum)
#      27     print('end loop')
# ---> 30 dfs(k=0, currsum=0)
#      31 return res
#
# Cell In[103], line 22, in comboSum.<locals>.dfs(k, currsum)
#      20 combo.append(nums[i])
#      21 print('first dfs')
# ---> 22 dfs(k + 1, currsum + nums[i])
#      24 combo.pop()
#      25 print('second dfs')
#
# Cell In[103], line 22, in comboSum.<locals>.dfs(k, currsum)
#      20 combo.append(nums[i])
#      21 print('first dfs')
# ---> 22 dfs(k + 1, currsum + nums[i])
#      24 combo.pop()
#      25 print('second dfs')
#
# Cell In[103], line 26, in comboSum.<locals>.dfs(k, currsum)
#      24 combo.pop()
#      25 print('second dfs')
# ---> 26 dfs(k + 1, currsum)
#      27 print('end loop')
#
# Cell In[103], line 26, in comboSum.<locals>.dfs(k, currsum)
#      24 combo.pop()
#      25 print('second dfs')
# ---> 26 dfs(k + 1, currsum)
#      27 print('end loop')
#
#     [... skipping similar frames: comboSum.<locals>.dfs at line 26 (2961 times)]
#
# Cell In[103], line 26, in comboSum.<locals>.dfs(k, currsum)
#      24 combo.pop()
#      25 print('second dfs')
# ---> 26 dfs(k + 1, currsum)
#      27 print('end loop')
#
# Cell In[103], line 22, in comboSum.<locals>.dfs(k, currsum)
#      20 combo.append(nums[i])
#      21 print('first dfs')
# ---> 22 dfs(k + 1, currsum + nums[i])
#      24 combo.pop()
#      25 print('second dfs')
#
# Cell In[103], line 9, in comboSum.<locals>.dfs(k, currsum)
#       5 def dfs(k, currsum):
#       7     i=k%len(nums)
# ----> 9     print(f'Current sum: {currsum}, Current combination: {combo}')
#      11     if currsum == target:
#      12         res.append(combo.copy())
#
# File ~/neetcode/venv/lib/python3.10/site-packages/ipykernel/iostream.py:664, in OutStream.write(self, string)
#     655 def write(self, string: str) -> Optional[int]:  # type:ignore[override]
#     656     """Write to current stream after encoding if necessary
#     657
#     658     Returns
#    (...)
#     662
#     663     """
# --> 664     parent = self.parent_header
#     666     if not isinstance(string, str):
#     667         msg = f"write() argument must be str, not {type(string)}"  # type:ignore[unreachable]
#
# File ~/neetcode/venv/lib/python3.10/site-packages/ipykernel/iostream.py:509, in OutStream.parent_header(self)
#     505 @property
#     506 def parent_header(self):
#     507     try:
#     508         # asyncio-specific
# --> 509         return self._parent_header.get()
#     510     except LookupError:
#     511         try:
#     512             # thread-specific
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
